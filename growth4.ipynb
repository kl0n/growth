# %%
# %run microbe2.py
import pandas as pd 
from io import StringIO

fn = '201208_dh5a_growth_curve.csv'
df, g = readPlates(fn)
display(df)
print(g)
# Out:
#         t     C17.0     C17.1     C17.2     C18.3     C18.4     C18.5  \
# 0     0.0  0.091638  0.097108  0.089995  0.082598  0.084995  0.081428
# 1    90.0  0.093527  0.099909  0.094283  0.085372  0.087701  0.084588
# 2   180.0  0.102339  0.106732  0.100887  0.092899  0.095603  0.093007
# 3   270.0  0.113780  0.118258  0.112899  0.104509  0.107645  0.105651
# 4   360.0  0.141508  0.144394  0.151309  0.132529  0.136437  0.137759
# 5  1260.0  0.393773  0.401710  0.398006  0.373460  0.384588  0.395315
#
#        C5.6      C5.7      C5.8  ...     S6.98    S13.99   S13.100   S13.101  \
# 0  0.071959  0.067861  0.071296  ...  0.085743  0.080549  0.084489  0.079135
# 1  0.081908  0.078098  0.081932  ...  0.090755  0.084620  0.087522  0.083116
# 2  0.105597  0.102576  0.107350  ...  0.100350  0.095676  0.097963  0.094367
# 3  0.135967  0.135709  0.140713  ...  0.114185  0.111791  0.113615  0.110610
# 4  0.185847  0.185953  0.194759  ...  0.143729  0.144512  0.146527  0.145254
# ...

# %%
# %run microbe2.py

d = growthAnalysis(df, g, 'dh5a')
# Out:
# C17
# C18
# C5
# C6
# C16
# C13
# C8
# C7
# C12
# C4
# C19
# C1
# C3
# C9
# C14
# C11
# C2
# C10
# C15
# C20
# C21
# S3
# S4
# S2
# S14
# S10
# S5
# S12
# S8
# S1
# S11
# S15
# S6
# S13
# S7
# S9

# %%
d
# Out:
#    sample  growth plateau min  growth plateau max  mean growth plateau  \
# 0     C17            0.393522            0.401580             0.397651
# 1     C18            0.373165            0.394958             0.384161
# 2      C5            0.377321            0.392798             0.384567
# 3      C6            0.471034            0.483777             0.475915
# 4     C16            0.228667            0.240442             0.235215
# 5     C13            0.253625            0.279603             0.263225
# 6      C8            0.407726            0.420649             0.413561
# 7      C7            0.221298            0.227335             0.224737
# 8     C12            0.292358            0.302454             0.297928
# 9      C4            0.307859            0.312456             0.309407
# 10    C19            0.391549            0.402922             0.397145
# 11     C1            0.189170            0.205227             0.195622
# ...

# %%
d.to_csv('dh5a_growth_analysis.csv', sep='\t')

# %%
fn = '201208_hme63_growth_curve.csv'
df, g = readPlates(fn)
display(df)
print(g)
# Out:
#         t     C17.0     C17.1     C17.2     C18.3     C18.4     C18.5  \
# 0     0.0  0.081611  0.080377  0.083273  0.078518  0.083587  0.081075
# 1    90.0  0.085673  0.087031  0.088158  0.084012  0.088681  0.089222
# 2   180.0  0.104084  0.106115  0.106064  0.105539  0.110155  0.114183
# 3   270.0  0.138011  0.139076  0.136594  0.149523  0.151884  0.158468
# 4   360.0  0.176875  0.181672  0.175403  0.199704  0.200620  0.216589
# 5  1440.0  0.473825  0.481752  0.463851  0.518885  0.510910  0.581956
#
#        C5.6      C5.7      C5.8  ...     S6.98    S13.99   S13.100   S13.101  \
# 0  0.222381  0.211108  0.207782  ...  0.097580  0.062737  0.070932  0.088215
# 1  0.308402  0.286544  0.280394  ...  0.102950  0.062394  0.071266  0.092736
# 2  0.436961  0.431597  0.421904  ...  0.129917  0.062670  0.073425  0.108513
# 3  0.636792  0.654922  0.629049  ...  0.177932  0.063140  0.078969  0.139273
# 4  0.834348  0.845529  0.777508  ...  0.229406  0.064743  0.093908  0.177977
# ...

# %%
h = growthAnalysis(df, g, 'hme63')
# Out:
# C17
# C18
# C5
# C6
# C16
# C13
# C8
# C7
# C12
# C4
# C19
# C1
# C3
# C9
# C14
# C11
# C2
# C10
# C15
# C20
# C21
# S3
# S4
# S2
# S14
# S10
# S5
# S12
# S8
# S1
# S11
# S15
# S6
# S13
# S7
# S9

# %%
h
# Out:
#    sample  growth plateau min  growth plateau max  mean growth plateau  \
# 0     C17            0.462103            0.485750             0.473732
# 1     C18            0.512025            0.581507             0.537420
# 2      C5            1.484298            1.538158             1.503008
# 3      C6            1.566039            1.617243             1.595873
# 4     C16            1.522115            1.577366             1.541803
# 5     C13            1.327689            1.442900             1.375653
# 6      C8            0.583669            0.602899             0.590615
# 7      C7            0.287110            0.307155             0.295323
# 8     C12            0.500055            0.514914             0.505883
# 9      C4            0.501763            0.544722             0.518267
# 10    C19            0.498339            0.551981             0.523207
# 11     C1            1.463907            1.506682             1.483193
# ...

# %%
h.to_csv('hme63_growth_analysis.csv', sep='\t')
